# %% [markdown]
# ## **Variables**
#
# ![image.png](attachment:image.png)
#
# #### Variable is a name of the memory location where data is stored. Once a variable is stored that means a space is allocated in memory.

# %% [markdown]
# ## Rules for variable names
#
# 1. In Variable names cannot start with a number.
# 2. There can be no spaces in the name, use _ instead.
# 3. Can't use any of these symbols :`'`,`"` ,`<>`,`/`,`?`,`|`,`\`,`()`,`!`,`@`,`#`,`$`,`%`,`^`,`&`,`*`,`~`,`-`,`+`
# 4. Avoid using the characters `'l' (lowercase letter)`, `'O' (uppercase letter)`.
# 5. Avoid using words that have special meaning in Python like **"list"** and **"str"**

# %% [markdown]
# ### Comments in python

# %% [markdown]
# #### Single line comment can be defined using the `"#"`

# %%
# How are you

# %% [markdown]
# #### Multi line comment can be defined using the `""" """`

# %%
"""
HOW ARE YOU
"""
# Out:
# '\nHOW ARE YOU\n'

# %% [markdown]
# ### Assigning Variables
#
# Variable assignment follows `name = object`, where a equals sign `=` is an assignment operator

# %%
x=5

# Here x is the variable and 5 is the value
# which means we x is the container and 5 is the value which is store in the x container or box

# %%
print(x)
# Out:
# 5

# %%
print(x+x)
# Out:
# 10

# %%
b=20

print(b)
# Out:
# 20

# %% [markdown]
# ### Using the variables to perform some mathmatical operation using variables

# %%
# Declare the variable a and assign the value 10 

a=10

b=20

# %%
print(a)
# Out:
# 10

# %%
print(b)
# Out:
# 20

# %%
# Addition of two numbers using variables

# Declare the c variable and assign the values

c=a+b

print(c)
# Out:
# 30

# %%
# substraction of two numbers using variables

x=24

y=6

print(x)
print(y)

print(x-y)

print(y-x)
# Out:
# 24
# 6
# 18
# -18

# %%
# Multiplication of two numbers using variables

a=10

b=5

print(a)

print(b)

print(a*b)
# Out:
# 10
# 5
# 50

# %%
# Divison of two numbers using variables

a=20

b=5

print(a/b)


print(a//b)
# Out:
# 4.0
# 4

# %% [markdown]
# ### Reassigning Variables

# %%
a=a+5  #20+5
print(a)
# Out:
# 25

# %%
a=a+10 # 25+10

print(a)
# Out:
# 35

# %%
a=a*10  #35*10

print(a)
# Out:
# 350

# %%
a=a/10  # 350/10
print(a)
# Out:
# 35.0

# %% [markdown]
# #### There's actually a shortcut for this. Python lets you add, subtract, multiply and divide numbers with reassignment using
# `+=, -=, *=, and /=`.

# %%
a+=10   # 35.0+10

print(a)
# Out:
# 45.0

# %%
a-=10  # 45.0-10
print(a)
# Out:
# 35.0

# %%
a*=4  #35*4

print(a)
# Out:
# 140.0

# %%
a/=5   # 140/5

print(a)
# Out:
# 28.0

# %%
a//=5    #20.0//5
print(a)
# Out:
# 5.0

# %%
28//5
# Out:
# 5

# %%
x=10

y=20

z=(x+y)
print(z)
# Out:
# 30

# %%
# Now the value for z is 30 Here we use the reassignment approach

# %%
z=10

# %%
print(z+10)
# Out:
# 20

# %%
# Here we can see that as we use the same variable z and assign the value 10 so herre we can see the output that is 20 (10+10)=20

# %%
print(z-5)
print(z)

# 10-5
# Out:
# 5
# 10

# %%
# Here we can see that first we assign the variable z with the value 10

# %%
m=10
n=20
print(m,n)
print(m+n)
print(m-n)
print(m*n)
# Out:
# 10 20
# 30
# -10
# 200

# %% [markdown]
# Determining variable type with type()
#
# You can check what type of object is assigned to a variable using Python's built-in type() function. Common data types include:
#
# - int (for integer)
# - float (for decimal point)
# - str (for string)
# - list (for list)
# - tuple (for tuple)
# - dict (for dictionary)
# - set (for set)
# - bool (for Boolean True/False)

# %% [markdown]
# #### To check the data type we can use the `type()` to see the type of variable

# %%
a=10

print(type(m))
# Out:
# <class 'int'>

# %%
b="alice"
print(type(b))
# Out:
# <class 'str'>

# %%
c=[1,3,4,5]
print(type(c))
# Out:
# <class 'list'>

# %%
d={"a":"55"}
print(type(d))
# Out:
# <class 'dict'>

# %%
e=(2,"a",12.4)
print(type(e))
# Out:
# <class 'tuple'>

# %%
f={"A",1,3.5}
print(type(f))
# Out:
# <class 'set'>

# %% [markdown]
# ### Multiple Assignment

# %% [markdown]
# #### Assigning single value to multiple variables

# %%
a=b=c=20

print(a)
print(b)
print(c)
# Out:
# 20
# 20
# 20

# %% [markdown]
# #### Assigning multiple value to multiple variables

# %%
x,y,z=10,20,30

print(x)
print(y)
print(z)
# Out:
# 10
# 20
# 30

# %% [markdown]
# #### Dynamic Typing
#
# Python uses dynamic typing, meaning you can reassign variables to different data types. This makes Python very flexible in assigning data types; it differs from other languages that are statically typed.

# %%
my_var=10

print(my_var)
# Out:
# 10

# %%
my_var="abc"
print(my_var)
# Out:
# abc
